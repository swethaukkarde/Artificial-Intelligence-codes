# %% [markdown]
# <a href="https://colab.research.google.com/github/swethaukkarde/Artificial-Intelligence-codes/blob/main/Forward_chaining_inference_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def forward_chaining(facts, rules):
    inferred = set(facts)
    applied = True

    while applied:
        applied = False
        for rule in rules:
            premises, conclusion = rule

            # Check if rule can be applied
            if premises.issubset(inferred) and conclusion not in inferred:
                inferred.add(conclusion)
                applied = True
                print(f"Rule fired: {premises} -> {conclusion}")

    return inferred

# %%
# Initial facts
facts = {'A', 'B'}

# Rules: (IF premises THEN conclusion)
rules = [
    (set(['A', 'B']), 'C'),
    (set(['C']), 'D'),
    (set(['D']), 'E')
]

# Run forward chaining
result = forward_chaining(facts, rules)

print("\nFinal inferred facts:")
print(result)
# Out:
# Rule fired: {'A', 'B'} -> C
# Rule fired: {'C'} -> D
# Rule fired: {'D'} -> E
#
# Final inferred facts:
# {'E', 'D', 'C', 'A', 'B'}
